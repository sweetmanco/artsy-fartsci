# %% [markdown]
# Download images locally to start training

# %%
# Import cell
import requests
import os
import shutil

# %%
# params
# eventually these will go in the .env etc but keep here for now
API_XAPP_TOKEN = ''

# %%
# Get 1000 artworks

url = 'https://api.artsy.net/api/artworks'
params = {'size':'500',
          #'offset':'201',
          'xapp_token':API_XAPP_TOKEN}
response = requests.get(url,params=params).json()

# get list of artworks only
artworks = response['_embedded']['artworks']

# %%
# iterate through artworks and get relevant info
artworks_ = []
for artwork in artworks:
    artwork_dict = {}
    artwork_dict['artwork_id'] = artwork['id']
    artwork_dict['title'] = artwork['title']
    artwork_dict['category'] = artwork['category']
    artwork_dict['medium'] = artwork['medium']
    artwork_dict['date'] = artwork['date']
    artwork_dict['height_cm'] = artwork['dimensions']['cm']['height']
    artwork_dict['width_cm'] = artwork['dimensions']['cm']['width']
    artwork_dict['depth_cm'] = artwork['dimensions']['cm']['depth']
    artwork_dict['diameter_cm'] = artwork['dimensions']['cm']['diameter']
    artwork_dict['collecting_institution'] = artwork['collecting_institution']
    # not every artwork has images so use try except
    try:
        artwork_dict['image_versions'] = artwork['image_versions']
        artwork_dict['image_url'] = artwork['_links']['image']['href']
        artwork_dict['image_url_is_template'] = artwork['_links']['image']['templated']
    except:
        artwork_dict['image_versions'] = None
        artwork_dict['image_url'] = None
        artwork_dict['image_url_is_template'] = None
    artworks_.append(artwork_dict)
    
# iterate through artworks and get list of image urls
for artwork in artworks_:
    image_urls = {}
    if artwork['image_url_is_template']:
        for version in artwork['image_versions']:
            image_urls[version] = artwork['image_url'].replace("{image_version}",version)
    artwork['image_url_all'] = image_urls

# %%
has_medium_list = []
for artwork in artworks_:
    if artwork['image_versions']:
        has_medium_list.append('medium' in artwork['image_versions'])
    else:
        has_medium_list.append(False)

# %%
[artwork for ix,artwork in enumerate(artworks_) if not has_medium_list[ix]]
# Out:
# [{'artwork_id': '5035a0ea33ed360002000705',
#   'title': 'The Flood of Noah (Genesis 7:11-24)',
#   'category': 'Sculpture',
#   'medium': 'Ink and pigment on parchment',
#   'date': 'ca. 1250',
#   'height_cm': 13.2,
#   'width_cm': 9.5,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/normalized.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/77uzE-BG0-tidzgXtnX8dQ/tall.jpg'}},
#  {'artwork_id': '5035a0eb33ed360002000713',
#   'title': 'Ancestors of Christ',
#   'category': 'Drawing, Collage or other Work on Paper',
#   'medium': 'Ink, paint and gold on parchment',
#   'date': '1262',
#   'height_cm': 61.4,
#   'width_cm': 21.4,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/normalized.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/ukX_wmBpODhKCacA8TwZxg/tall.jpg'}},
#  {'artwork_id': '5035a0eb9e387b00020006f1',
#   'title': "Joseph's Dream",
#   'category': 'Drawing, Collage or other Work on Paper',
#   'medium': 'Ink, paint and gold on parchment',
#   'date': '1262',
#   'height_cm': 30.0,
#   'width_cm': 21.4,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/oonGjlNmYL8_08A5SYevPw/tall.jpg'}},
#  {'artwork_id': '5035a0eb9e387b00020006f8',
#   'title': 'Christ Predicting the Sufferings of the Apostles',
#   'category': 'Drawing, Collage or other Work on Paper',
#   'medium': 'Ink, paint and gold on parchment',
#   'date': '1262',
#   'height_cm': 30.0,
#   'width_cm': 21.4,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/small.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/hBlVB4Uf7znmozFZHiVHyw/tall.jpg'}},
#  {'artwork_id': '5035a0ec33ed36000200071a',
#   'title': 'An Old Sufi Laments His Lost Youth',
#   'category': 'Drawing, Collage or other Work on Paper',
#   'medium': 'Ink and pigments on laid paper',
#   'date': '1597-1598',
#   'height_cm': 72.4,
#   'width_cm': 48.3,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/0AsIyWpTqhJ82m3-NYq_KA/tall.jpg'}},
#  {'artwork_id': '5035a0edf852da00020006f4',
#   'title': 'Seated Buddha in the Attitude of Preaching',
#   'category': 'Sculpture',
#   'medium': 'Phyllite',
#   'date': '2nd-3rd century ',
#   'height_cm': 63.0,
#   'width_cm': None,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/p0QpX9jNON_GcAFTw9D3GA/tall.jpg'}},
#  {'artwork_id': '5035a0ef6cb802000200075e',
#   'title': 'Painted Fire Screen',
#   'category': 'Painting',
#   'medium': 'Oil on fabric',
#   'date': '1700',
#   'height_cm': 221.0,
#   'width_cm': 297.2,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': 'The Walters Art Museum',
#   'image_versions': None,
#   'image_url': None,
#   'image_url_is_template': None,
#   'image_url_all': {}},
#  {'artwork_id': '5035a0f2f852da0002000717',
#   'title': 'At the Café',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': 'ca. 1879',
#   'height_cm': 47.3,
#   'width_cm': 39.1,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/du2FSLbpDQyRLcJ9Sr9ejw/tall.jpg'}},
#  {'artwork_id': '5035a0f5609739000200074e',
#   'title': 'Reliquary Panel of the Triumphant Christ ',
#   'category': 'Mixed Media',
#   'medium': 'Silver, gilded silver with Champlevé enamel, and horn (bovine)',
#   'date': 'Late 11th century',
#   'height_cm': 58.6,
#   'width_cm': 37.9,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': 'The Walters Art Museum',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/l7VfkY0jXoZGRw6dnQ0WMQ/tall.jpg'}},
#  {'artwork_id': '5035a0f9aadc3100020007da',
#   'title': 'Two Panels depicting the Annunciation, Baptism of Christ and Crucifixion from the Antwerp-Baltimore Quadriptych',
#   'category': 'Painting',
#   'medium': 'Oil and tempera(?) with gold leaf on panel',
#   'date': 'ca. 1400',
#   'height_cm': 37.1,
#   'width_cm': 26.5,
#   'depth_cm': 2.1,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/O8djlNzkFvPFXk8LaMUjEw/tall.jpg'}},
#  {'artwork_id': '5035a0faaadc3100020007e1',
#   'title': 'Politics in an Oyster House ',
#   'category': 'Painting',
#   'medium': 'Oil on fabric',
#   'date': '1848',
#   'height_cm': 41.3,
#   'width_cm': 33.2,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': '',
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/MRXQYWv92gt2m70uArtpZg/tall.jpg'}},
#  {'artwork_id': '506dfe9279fb8700020005ff',
#   'title': "Dans un café (L'absinthe)",
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1875-1876',
#   'height_cm': 92.0,
#   'width_cm': 68.0,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': "Musée d'Orsay, Paris",
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/large.jpg',
#    'large_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/large_rectangle.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/WhEYWJVogdUhFdq47Vnxtw/tall.jpg'}},
#  {'artwork_id': '507db15bd9c3650002002ac0',
#   'title': 'Young Spartans Exercising',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': 'ca. 1860',
#   'height_cm': 109.2,
#   'width_cm': 154.3,
#   'depth_cm': None,
#   'diameter_cm': None,
#   'collecting_institution': 'National Gallery, London',
#   'image_versions': ['large',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/{image_version}.jpg',
#   'image_url_is_template': True,
#   'image_url_all': {'large': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/large.jpg',
#    'larger': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/larger.jpg',
#    'medium_rectangle': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/medium_rectangle.jpg',
#    'normalized': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/normalized.jpg',
#    'small': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/small.jpg',
#    'square': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/square.jpg',
#    'tall': 'https://d32dm0rphc51dk.cloudfront.net/-gYkXWcXljRe7-dhtcKM-Q/tall.jpg'}}]

# %%
# create /data folder - if it already exists, delete and recreate 
path = './data'
if not os.path.exists(path):
  os.mkdir(path)
  print("Folder %s created!" % path)
else:
    shutil.rmtree(path)
    os.mkdir(path)
    print("Folder deleted and recreated")
# Out:
# Folder deleted and recreated

# %%
# loop through images, download to local file in /data folder
no_without_medium = 0
for artwork in artworks_:
    
    try:
        url = artwork['image_url_all']['medium']
        file_name = f"data/{artwork['title']}.jpg"
        # This statement requests the resource at
        # the given link, extracts its contents
        # and saves it in a variable
        data = requests.get(url).content
        
        # Opening a new file named img with extension .jpg
        # This file would store the data of the image file
        f = open(file_name,'wb')
        
        # Storing the image data inside the data variable to the file
        f.write(data)
        f.close()
    except:
        no_without_large +=1

# %%
# When finished - delete data folder before pushing to git
