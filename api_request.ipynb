# %%
import requests
import pandas as pd
import numpy as np
import time

# %%
finals = []
offset = 0
artworks_df = pd.DataFrame(columns=('artwork_id','title','category','medium','date','height_cm','width_cm','image_versions','image_url','collecting_institution','image_url_is_template'))

# %%
# url = 'https://api.artsy.net/api/genes'

while offset < 200000:
    params = {'size':'100',
              'offset':offset,
#               'gene_id':'531df66f275b24e993000009',
              'xapp_token':'eyJhbGciOiJIUzI1NiJ9..FI2Y7A9Ry1MRaq_N6MdSWyOBXwro4PTUzzHt0TL6aKs'}

    url = 'https://api.artsy.net/api/artworks?'

    response = requests.get(url,params=params).json()

    artworks = response['_embedded']['artworks']
#     artworks_ = [] 

    for artwork in artworks:
        artwork_dict = {}
        artwork_dict['artwork_id'] = artwork['id']
        artwork_dict['title'] = artwork['title']
        artwork_dict['category'] = artwork['category']
        artwork_dict['medium'] = artwork['medium']
        artwork_dict['date'] = artwork['date']
        artwork_dict['height_cm'] = artwork['dimensions']['cm']['height']
        artwork_dict['width_cm'] = artwork['dimensions']['cm']['width']
    
        try:
            artwork_dict['image_versions'] = artwork['image_versions']
            artwork_dict['image_url'] = artwork['_links']['image']['href']
            artwork_dict['image_url_is_template'] = artwork['_links']['image']['templated']
            artwork_dict['collecting_institution'] = artwork['collecting_institution']

        except:
            artwork_dict['image_versions'] = None
            artwork_dict['image_url'] = None
            artwork_dict['image_url_is_template'] = None
#         artworks_.append(artwork_dict)
        artworks_temp = pd.DataFrame([artwork_dict])
        artworks_df = pd.concat([artworks_df, artworks_temp], ignore_index=True)
#     finals.append(artworks_)
    offset+=100
    time.sleep(.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [27], line 13
#       9     url = 'https://api.artsy.net/api/artworks?'
#      11     response = requests.get(url,params=params).json()
# ---> 13     artworks = response['_embedded']['artworks']
#      14 #     artworks_ = []
#      16     for artwork in artworks:
#
# KeyError: '_embedded'

# %%
artworks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26000 entries, 0 to 25999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   artwork_id              26000 non-null  object
#  1   title                   26000 non-null  object
#  2   category                25999 non-null  object
#  3   medium                  25998 non-null  object
#  4   date                    26000 non-null  object
#  5   height_cm               12680 non-null  float64
#  6   width_cm                12504 non-null  float64
#  7   image_versions          25893 non-null  object
#  8   image_url               25893 non-null  object
#  9   collecting_institution  25893 non-null  object
#  10  image_url_is_template   25893 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 2.2+ MB

# %%
artworks_df.head()
# Out:
#                  artwork_id  \
# 0  4d8b92eb4eb68a1b2c000968
# 1  4d8b92ee4eb68a1b2c0009ab
# 2  4d8b93394eb68a1b2c0010fa
# 3  4d8b937c4eb68a1b2c001722
# 4  4d8b93b04eb68a1b2c001b9d
#
#                                                title  category  \
# 0                                Der Kuss (The Kiss)  Painting
# 1                                   The Third of May  Painting
# 2  The Company of Frans Banning Cocq and Willem v...  Painting
# 3                                          Mona Lisa  Painting
# 4    Luncheon on the Grass (Le Déjeuner sur l'herbe)  Painting
#
#                         medium           date  height_cm  width_cm  \
# 0  Oil and gold leaf on canvas      1907-1908      180.1     180.1
# 1                Oil on canvas           1814      266.2     345.2
# 2                Oil on canvas           1642      363.2     437.4
# 3                Oil on poplar  ca. 1503-1506       77.0      53.1
# 4                Oil on canvas           1863      208.3     264.2
#
#                                       image_versions  \
# 0  [large, larger, medium, medium_rectangle, norm...
# 1  [square, small, large_rectangle, large, tall, ...
# 2  [large, large_rectangle, larger, medium, mediu...
# 3  [large, large_rectangle, larger, medium, mediu...
# 4  [large, large_rectangle, larger, medium_rectan...
#
#                                            image_url  \
# 0  https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa...
# 1  https://d32dm0rphc51dk.cloudfront.net/m4X41Fun...
# 2  https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVm...
# 3  https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_...
# 4  https://d32dm0rphc51dk.cloudfront.net/zFA7cwdk...
#
#                       collecting_institution image_url_is_template
# 0  Österreichische Galerie Belvedere, Vienna                  True
# 1           Museo Nacional del Prado, Madrid                  True
# 2                     Rijksmuseum, Amsterdam                  True
# 3                            Musée du Louvre                  True
# 4                       Musée d'Orsay, Paris                  True

# %%
artworks_df['category'].value_counts()
# Out:
# Print                                      15893
# Drawing, Collage or other Work on Paper     4295
#                                             2257
# Painting                                    2060
# Sculpture                                    817
# Photography                                  414
# Design/Decorative Art                         82
# Other                                         62
# Architecture                                  46
# Books and Portfolios                          37
# Mixed Media                                   17
# Textile Arts                                  13
# Posters                                        6
# Name: category, dtype: int64

# %%
artworks_df['image_versions'].value_counts()
# Out:
# [large, large_rectangle, larger, medium, medium_rectangle, normalized, small, square, tall]    7401
# [large_rectangle, larger, medium, medium_rectangle, normalized, small, square, tall]           2949
# [large, large_rectangle, larger, medium, medium_rectangle, normalized, small, square]          2595
# [large, large_rectangle, larger, medium, medium_rectangle, normalized, small, tall]            2310
# [large, large_rectangle, larger, medium, medium_rectangle, normalized, square, tall]           2142
#                                                                                                ...
# [large_rectangle, larger, small, square]                                                          1
# [large_rectangle, larger, square]                                                                 1
# [large, larger, small, square]                                                                    1
# [large_rectangle, larger, medium, medium_rectangle, normalized, small, square, tall, large]       1
# [large_rectangle, larger, tall]                                                                   1
# Name: image_versions, Length: 448, dtype: int64

# %%
a = 1
# artworks_df.loc[artworks_df['image_versions'].isna().index, 'image_versions']= [a for x in artworks_df[artworks_df['image_versions'].isna()]['image_versions']]
artworks_df['image_versions'].fillna(1)
# Out:
# 0        [large, larger, medium, medium_rectangle, norm...
# 1        [square, small, large_rectangle, large, tall, ...
# 2        [large, large_rectangle, larger, medium, mediu...
# 3        [large, large_rectangle, larger, medium, mediu...
# 4        [large, large_rectangle, larger, medium_rectan...
#                                ...
# 25995    [large, large_rectangle, larger, medium, mediu...
# 25996    [large, large_rectangle, larger, medium, mediu...
# 25997    [large, large_rectangle, larger, medium, mediu...
# 25998    [large, large_rectangle, larger, medium, mediu...
# 25999    [large, large_rectangle, larger, medium, mediu...
# Name: image_versions, Length: 26000, dtype: object

# %%
pd.Series([[] for x in range(107)], index=artworks_df[artworks_df['image_versions'].isna()].index)
# Out:
# 272      []
# 870      []
# 1221     []
# 1363     []
# 1962     []
#          ..
# 24511    []
# 24512    []
# 24513    []
# 24514    []
# 24515    []
# Length: 107, dtype: object

# %%
artworks_df.loc[artworks_df[artworks_df['image_versions'].isna()].index, 'image_versions'] = pd.Series([[] for x in range(107)], index=artworks_df[artworks_df['image_versions'].isna()].index)

# %%
artworks_df["large"] = artworks_df['image_versions'].apply(lambda x: "large" in x)
artworks_df["large_rectangle"] = artworks_df['image_versions'].apply(lambda x: "large_rectangle" in x)
artworks_df["larger"] = artworks_df['image_versions'].apply(lambda x: "larger" in x)
artworks_df["medium"] = artworks_df['image_versions'].apply(lambda x: "medium" in x)
artworks_df["medium_rectangle"] = artworks_df['image_versions'].apply(lambda x: "medium_rectangle" in x)
artworks_df["normalized"] = artworks_df['image_versions'].apply(lambda x: "normalized" in x)
artworks_df["small"] = artworks_df['image_versions'].apply(lambda x: "small" in x)
artworks_df["square"] = artworks_df['image_versions'].apply(lambda x: "square" in x)
artworks_df["tall"] = artworks_df['image_versions'].apply(lambda x: "tall" in x)

# %%
artworks_df
# Out:
#                      artwork_id  \
# 0      4d8b92eb4eb68a1b2c000968
# 1      4d8b92ee4eb68a1b2c0009ab
# 2      4d8b93394eb68a1b2c0010fa
# 3      4d8b937c4eb68a1b2c001722
# 4      4d8b93b04eb68a1b2c001b9d
# ...                         ...
# 25995  53559d87cd530e850c000166
# 25996  53559fedb202a3262000016a
# 25997  5357d09c7622dd0ff400002a
# 25998  5357d2cfa09a679102000045
# 25999  5357d5288b3b813fcd00004a
#
#                                                    title  category  medium  \
# 0                                    Der Kuss (The Kiss)  Painting    True
# 1                                       The Third of May  Painting    True
# 2      The Company of Frans Banning Cocq and Willem v...  Painting    True
# 3                                              Mona Lisa  Painting    True
# 4        Luncheon on the Grass (Le Déjeuner sur l'herbe)  Painting    True
# ...                                                  ...       ...     ...
# 25995  View of Houses in Delft, Known as ‘The Little ...  Painting    True
# 25996                             The Battle of Terheide  Painting    True
# 25997     Isaac and Rebecca, Known as ‘The Jewish Bride’  Painting    True
# 25998           Portrait of a Woman, Possibly Maria Trip  Painting    True
# 25999  The Wardens of the Amsterdam Drapers’ Guild, K...  Painting    True
#
#                  date  height_cm  width_cm  \
# 0           1907-1908      180.1     180.1
# 1                1814      266.2     345.2
# 2                1642      363.2     437.4
# 3       ca. 1503-1506       77.0      53.1
# 4                1863      208.3     264.2
# ...               ...        ...       ...
# 25995        ca. 1658       54.3      44.0
# 25996            1657      170.0     289.0
# 25997  ca. 1665 -1669      121.5     166.5
# 25998            1639      107.0      82.0
# 25999            1662      191.5     279.0
#
#                                           image_versions  \
# 0      [large, larger, medium, medium_rectangle, norm...
# 1      [square, small, large_rectangle, large, tall, ...
# 2      [large, large_rectangle, larger, medium, mediu...
# 3      [large, large_rectangle, larger, medium, mediu...
# 4      [large, large_rectangle, larger, medium_rectan...
# ...                                                  ...
# 25995  [large, large_rectangle, larger, medium, mediu...
# 25996  [large, large_rectangle, larger, medium, mediu...
# 25997  [large, large_rectangle, larger, medium, mediu...
# 25998  [large, large_rectangle, larger, medium, mediu...
# 25999  [large, large_rectangle, larger, medium, mediu...
#
#                                                image_url  \
# 0      https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa...
# 1      https://d32dm0rphc51dk.cloudfront.net/m4X41Fun...
# 2      https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVm...
# 3      https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_...
# 4      https://d32dm0rphc51dk.cloudfront.net/zFA7cwdk...
# ...                                                  ...
# 25995  https://d32dm0rphc51dk.cloudfront.net/6sSY1BE4...
# 25996  https://d32dm0rphc51dk.cloudfront.net/fOlaqjoa...
# 25997  https://d32dm0rphc51dk.cloudfront.net/T8zyOM1P...
# 25998  https://d32dm0rphc51dk.cloudfront.net/UJxHMaBg...
# 25999  https://d32dm0rphc51dk.cloudfront.net/kZMo5_gj...
#
#                           collecting_institution image_url_is_template  large  \
# 0      Österreichische Galerie Belvedere, Vienna                  True   True
# 1               Museo Nacional del Prado, Madrid                  True   True
# 2                         Rijksmuseum, Amsterdam                  True   True
# 3                                Musée du Louvre                  True   True
# 4                           Musée d'Orsay, Paris                  True   True
# ...                                          ...                   ...    ...
# 25995                                                             True   True
# 25996                                                             True   True
# 25997                                                             True   True
# 25998                                                             True   True
# 25999                                                             True   True
#
#        large_rectangle  larger  medium_rectangle  normalized  small  square  \
# 0                False    True              True        True   True    True
# 1                 True    True              True        True   True    True
# 2                 True    True              True        True   True    True
# 3                 True    True              True        True   True    True
# 4                 True    True              True        True   True    True
# ...                ...     ...               ...         ...    ...     ...
# 25995             True    True              True        True   True    True
# 25996             True    True              True        True   True    True
# 25997             True    True              True        True   True    True
# 25998             True    True              True        True   True    True
# 25999             True    True              True        True   True    True
#
#        tall
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ...     ...
# 25995  True
# 25996  True
# 25997  True
# 25998  True
# 25999  True
#
# [26000 rows x 19 columns]
