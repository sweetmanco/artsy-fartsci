# %%
import requests

# %%
# url = 'https://api.artsy.net/api/genes'
params = {'size':'10',
          'gene_id':'531df66f275b24e993000009',
          'xapp_token':'eyJhbGciOiJIUzI1NiJ9..FI2Y7A9Ry1MRaq_N6MdSWyOBXwro4PTUzzHt0TL6aKs'}
# https://api.artsy.net/api/artworks?gene_id=painting
api.artsy.net/api/artworks?gene_id=50c8ad5eea1617053e000212
# genes = '4d90d18edcdd5f44a5000010'

url = 'https://api.artsy.net/api/genes/531df66f275b24e993000009'

response = requests.get(url,params=params).json()

artworks = response['_embedded']['artworks']

artworks_ = []

for artwork in artworks:
    artwork_dict = {}
    artwork_dict['artwork_id'] = artwork['id']
    artwork_dict['title'] = artwork['title']
    artwork_dict['category'] = artwork['category']
    artwork_dict['medium'] = artwork['medium']
    artwork_dict['date'] = artwork['date']
    artwork_dict['height_cm'] = artwork['dimensions']['cm']['height']
    artwork_dict['width_cm'] = artwork['dimensions']['cm']['width']
    
    try:
        artwork_dict['image_versions'] = artwork['image_versions']
        artwork_dict['image_url'] = artwork['_links']['image']['href']
        artwork_dict['image_url_is_template'] = artwork['_links']['image']['templated']
        artwork_dict['collecting_institution'] = artwork['collecting_institution']
        
    except:
        artwork_dict['image_versions'] = None
        artwork_dict['image_url'] = None
        artwork_dict['image_url_is_template'] = None
    artworks_.append(artwork_dict)
    
for artwork in artworks_:
    image_urls = []
    if artwork['image_url_is_template']:
        for version in artwork['image_versions']:
            image_urls.append((artwork['image_url'].replace("{image_version}",version)))
    artwork['image_url_all'] = image_urls
# Out:
#   Cell In [28], line 6
#     api.artsy.net/api/artworks?gene_id=50c8ad5eea1617053e000212
#                                         ^
# SyntaxError: invalid decimal literal

# %%
len(artworks_)
# Out:
# 10

# %%
artworks_
# Out:
# [{'artwork_id': '4d8b92eb4eb68a1b2c000968',
#   'title': 'Der Kuss (The Kiss)',
#   'category': 'Painting',
#   'medium': 'Oil and gold leaf on canvas',
#   'date': '1907-1908',
#   'height_cm': 180.1,
#   'width_cm': 180.1,
#   'image_versions': ['large',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Österreichische Galerie Belvedere, Vienna',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/NOpIAwQa-3r51Cg9qXKbfA/tall.jpg']},
#  {'artwork_id': '4d8b92ee4eb68a1b2c0009ab',
#   'title': 'The Third of May',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1814',
#   'height_cm': 266.2,
#   'width_cm': 345.2,
#   'image_versions': ['square',
#    'small',
#    'large_rectangle',
#    'large',
#    'tall',
#    'medium',
#    'medium_rectangle',
#    'larger',
#    'normalized'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Museo Nacional del Prado, Madrid',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/tall.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/m4X41Fun8gpDjn7Gat9cUg/normalized.jpg']},
#  {'artwork_id': '4d8b93394eb68a1b2c0010fa',
#   'title': 'The Company of Frans Banning Cocq and Willem van Ruytenburch (The Night Watch)',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1642',
#   'height_cm': 363.2,
#   'width_cm': 437.4,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Rijksmuseum, Amsterdam',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/IG8ZLvVmZgQiTn2zK0Bp8w/tall.jpg']},
#  {'artwork_id': '4d8b937c4eb68a1b2c001722',
#   'title': 'Mona Lisa',
#   'category': 'Painting',
#   'medium': 'Oil on poplar',
#   'date': 'ca. 1503-1506',
#   'height_cm': 77.0,
#   'width_cm': 53.1,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Musée du Louvre',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/5L1xjKC_und1uiKCpUPHhw/tall.jpg']},
#  {'artwork_id': '4d8b93b04eb68a1b2c001b9d',
#   'title': "Luncheon on the Grass (Le Déjeuner sur l'herbe)",
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1863',
#   'height_cm': 208.3,
#   'width_cm': 264.2,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall',
#    'medium'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': "Musée d'Orsay, Paris",
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/tall.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/zFA7cwdkWxbIrmuAAd21VA/medium.jpg']},
#  {'artwork_id': '4eaeecc3d2a5820001006e93',
#   'title': 'The Birth of Venus',
#   'category': 'Painting',
#   'medium': 'Tempera on canvas',
#   'date': 'ca. 1486\n',
#   'height_cm': 172.7,
#   'width_cm': 278.6,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Uffizi Gallery, Florence',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/2VgTXzq3A2p5vTxxosS4zg/tall.jpg']},
#  {'artwork_id': '4eaeedd66899c800010066ac',
#   'title': 'The Birth of Venus',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1863',
#   'height_cm': 130.0,
#   'width_cm': 225.3,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': "Musée d'Orsay, Paris",
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/79EkzLz-LMtBTfnd7ae4WA/tall.jpg']},
#  {'artwork_id': '4eaef38fec5cf6000100a3f9',
#   'title': 'The Calling of St Matthew',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1599-1600',
#   'height_cm': 322.3,
#   'width_cm': 340.4,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'San Luigi dei Francesi, Rome',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/rqoQ0ln0TqFAf7GcVwBtTw/tall.jpg']},
#  {'artwork_id': '4eaefa6c76e78f0001009d40',
#   'title': 'The Burial At Ornans',
#   'category': 'Painting',
#   'medium': 'Oil on canvas',
#   'date': '1849-1850',
#   'height_cm': 315.2,
#   'width_cm': 660.4,
#   'image_versions': ['large',
#    'large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': "Musée d'Orsay, Paris",
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/large.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/RXCPBByq2cmCpXfAM3g-HQ/tall.jpg']},
#  {'artwork_id': '4eaefc4976e78f0001009e86',
#   'title': 'The Last Supper',
#   'category': 'Painting',
#   'medium': 'Tempera on gesso, pitch and mastic',
#   'date': '1495-1498',
#   'height_cm': 460.2,
#   'width_cm': 880.6,
#   'image_versions': ['large_rectangle',
#    'larger',
#    'medium',
#    'medium_rectangle',
#    'normalized',
#    'small',
#    'square',
#    'tall'],
#   'image_url': 'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/{image_version}.jpg',
#   'image_url_is_template': True,
#   'collecting_institution': 'Santa Maria delle Grazie, Milan',
#   'image_url_all': ['https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/large_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/larger.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/medium.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/medium_rectangle.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/normalized.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/small.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/square.jpg',
#    'https://d32dm0rphc51dk.cloudfront.net/jI0TpkGaAoJ9JL4s4JPdBg/tall.jpg']}]
